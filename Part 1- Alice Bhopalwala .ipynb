# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
#This data can be obtained at data world https://query.data.world/s/zpfwdyw2eisrcwdwnb44lcr5zb6vvs
data= pd.read_csv("https://query.data.world/s/zpfwdyw2eisrcwdwnb44lcr5zb6vvs")

# %%
#TITLE: POKEMON
data
# Out:
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass  Poison    318   45      49
# 1      2                    Ivysaur     Grass  Poison    405   60      62
# 2      3                   Venusaur     Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4      4                 Charmander      Fire     NaN    309   39      52
# 5      5                 Charmeleon      Fire     NaN    405   58      64
# 6      6                  Charizard      Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9      7                   Squirtle     Water     NaN    314   44      48
# 10     8                  Wartortle     Water     NaN    405   59      63
# 11     9                  Blastoise     Water     NaN    530   79      83
# ...

# %%
data.groupby("Legendary")

# %%
stats=data.groupby("Legendary").describe()
stats.shape
# Out:
# (2, 72)

# %%
#for all the pokemons with legendary attribute as false have a collective stats as:
stats.iloc[0]
# Out:
# #           count    735.000000
#             mean     353.315646
#             std      208.590419
#             min        1.000000
#             25%      175.500000
#             50%      346.000000
#             75%      533.500000
#             max      715.000000
# Attack      count    735.000000
#             mean      75.669388
#             std       30.490153
#             min        5.000000
#             25%       54.500000
#             50%       72.000000
#             75%       95.000000
#             max      185.000000
# Defense     count    735.000000
#             mean      71.559184
#             std       30.408194
#             min        5.000000
#             25%       50.000000
#             50%       66.000000
#             75%       85.000000
#             max      230.000000
# Generation  count    735.000000
#             mean       3.284354
#             std        1.673471
#             min        1.000000
#             25%        2.000000
# ...

# %%
#for all the pokemons with legendary atribute as true have collective stats as:
stats.iloc[1]
# Out:
# #           count     65.000000
#             mean     470.215385
#             std      173.651095
#             min      144.000000
#             25%      381.000000
#             50%      483.000000
#             75%      642.000000
#             max      721.000000
# Attack      count     65.000000
#             mean     116.676923
#             std       30.348037
#             min       50.000000
#             25%      100.000000
#             50%      110.000000
#             75%      131.000000
#             max      190.000000
# Defense     count     65.000000
#             mean      99.661538
#             std       28.255131
#             min       20.000000
#             25%       90.000000
#             50%      100.000000
#             75%      115.000000
#             max      200.000000
# Generation  count     65.000000
#             mean       3.769231
#             std        1.455262
#             min        1.000000
#             25%        3.000000
# ...

# %%
#random 15 samples from the data
data.sample(15)
# Out:
#        #                   Name    Type 1    Type 2  Total   HP  Attack  \
# 273  253                Grovyle     Grass       NaN    405   50      65
# 173  159               Croconaw     Water       NaN    405   65      80
# 657  596             Galvantula       Bug  Electric    472   70      77
# 593  533                Gurdurr  Fighting       NaN    405   85     105
# 170  156                Quilava      Fire       NaN    405   58      64
# 437  392              Infernape      Fire  Fighting    534   76     104
# 791  715                Noivern    Flying    Dragon    535   85      70
# 552  493                 Arceus    Normal       NaN    720  120     120
# 414  377               Regirock      Rock       NaN    580   80     100
# 780  710  PumpkabooAverage Size     Ghost     Grass    335   49      66
# 798  720     HoopaHoopa Unbound   Psychic      Dark    680   80     160
# 68    63                   Abra   Psychic       NaN    310   25      20
# ...

# %%
#number of rows and columns
data.shape
# Out:
# (800, 13)

# %%
data.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
#information on data types
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# Total         800 non-null int64
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
#info on file size
data.memory_usage(index=True).sum()
# Out:
# 77680

# %%
# summary of all the column names
list(data)
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'Total',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary']
