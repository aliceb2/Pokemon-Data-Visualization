# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://query.data.world/s/zpfwdyw2eisrcwdwnb44lcr5zb6vvs')

# %%
df
# Out:
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass  Poison    318   45      49
# 1      2                    Ivysaur     Grass  Poison    405   60      62
# 2      3                   Venusaur     Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4      4                 Charmander      Fire     NaN    309   39      52
# 5      5                 Charmeleon      Fire     NaN    405   58      64
# 6      6                  Charizard      Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9      7                   Squirtle     Water     NaN    314   44      48
# 10     8                  Wartortle     Water     NaN    405   59      63
# 11     9                  Blastoise     Water     NaN    530   79      83
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.shape
# Out:
# (800, 13)

# %%
df.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
df["Type 1"].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
df.groupby("Type 1")["Attack"].count().describe()
# Out:
# count     18.000000
# mean      44.444444
# std       27.901554
# min        4.000000
# 25%       27.250000
# 50%       32.000000
# 75%       55.750000
# max      112.000000
# Name: Attack, dtype: float64

# %%
pokemon_type1 = df['Type 1'].value_counts()
pokemon_type1
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Dragon       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
pokemon_type1.plot.bar()
plt.title('Pokemon type1 distribution')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %%
pokemon_type1.to_frame()
# Out:
#           Type 1
# Water        112
# Normal        98
# Grass         70
# Bug           69
# Psychic       57
# Fire          52
# Rock          44
# Electric      44
# Ground        32
# Dragon        32
# Ghost         32
# Dark          31
# Poison        28
# Steel         27
# Fighting      27
# Ice           24
# Fairy         17
# Flying         4

# %%
plt.plot(df["Attack"], marker = '.', linewidth = 1.0)
plt.xlabel("Attack value")
plt.ylabel("Num of Pokemon")
plt.show()

# %% [markdown]
# Project part1 report:
#
# •	What is the "name" of the dataset?
#
#     The name of our dataset is “Pokemon With Stats”.
#
# •	Where did you obtain it?
#
#     We obtain this dataset from data.world. Our group members explore several datasets individually and finally decide to use this pokemon dataset.
#
# •	Where can we obtain it? (i.e., URL)
#
#     https://query.data.world/s/zpfwdyw2eisrcwdwnb44lcr5zb6vvs
#
# •	What is the license of the dataset? What are we allowed to do with it?
#
#     This dataset is released under CC0: Public Domain, which means that "no copyright reserved" option. Therefore, we are allowed to do all kinds of manipulations and operations.
#
# •	How big is it in file size and in items?
#
#     This data is only 45 KB, with relevant stats of 721 Pokemon.
#
# •	Summarize the characteristics of the dataset
#
#     This dataset includes 721 Pokemon, including their number, name, first and second type, and basic stats: HP, Attack, Defense, Special Attack, Special Defense, and Speed. There are 13 columns which are the number and attributes listed above. And there are 800 rows, this is because for several pokemon, they have different rows for different sizes.
#
#     For the attributes list above, the data types are:
#     Name          object
#     Type 1        object
#     Type 2        object
#     Total         int64
#     HP            int64
#     Attack        int64
#     Defense       int64
#     Sp. Atk       int64
#     Sp. Def       int64
#     Speed         int64
#     Generation    int64
#     Legendary     bool
